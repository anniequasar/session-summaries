# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
import os
os.listdir()
# Out:
# ['.config', 'COVID19_line_list_data.csv', 'sample_data']

# %%
df_confirmed = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv')

# %%
df_recovered = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Recovered.csv')

# %%
df_death = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Deaths.csv')

# %%
df_confirmed.shape, df_recovered.shape, df_death.shape
# Out:
# ((463, 59), (463, 59), (463, 59))

# %%
df_confirmed.head(3)
# Out:
#   Province/State Country/Region      Lat  ...  3/14/20  3/15/20  3/16/20
# 0            NaN       Thailand  15.0000  ...       82      114      147
# 1            NaN          Japan  36.0000  ...      773      839      825
# 2            NaN      Singapore   1.2833  ...      212      226      243
#
# [3 rows x 59 columns]

# %%
df_recovered.head(3)
# Out:
#   Province/State Country/Region      Lat  ...  3/14/20  3/15/20  3/16/20
# 0            NaN       Thailand  15.0000  ...       35       35       35
# 1            NaN          Japan  36.0000  ...      118      118      144
# 2            NaN      Singapore   1.2833  ...      105      105      109
#
# [3 rows x 59 columns]

# %%
df_death.head(3)
# Out:
#   Province/State Country/Region      Lat  ...  3/14/20  3/15/20  3/16/20
# 0            NaN       Thailand  15.0000  ...        1        1        1
# 1            NaN          Japan  36.0000  ...       22       22       27
# 2            NaN      Singapore   1.2833  ...        0        0        0
#
# [3 rows x 59 columns]

# %%
def plot_covid(country_name='Australia', option='deaths'):
    """
    country_name - country name from the data
    option - confirmed, recovered, deaths
    """
    if option == 'confirmed':
        df = df_confirmed.copy()
    elif option == 'recovered':
        df = df_recovered.copy()
    else:
        df = df_death.copy()
    
    country_data = df.groupby('Country/Region').agg('sum').loc[country_name,'1/22/20':]
    return px.line(x=country_data.index, y = country_data.values)

# %%
px.scatter_geo(df_confirmed, lat='Lat',lon='Long',color='Country/Region', size='3/16/20')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="57976971-0db5-4e10-a2c4-6403cc0b2f92" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("57976971-0db5-4e10-a2c4-6403cc0b2f92")) {
#                     Plotly.newPlot(
#                         '57976971-0db5-4e10-a2c4-6403cc0b2f92',
# ...

# %%
import os
os.listdir()
# Out:
# ['.config', 'COVID19_line_list_data.csv', 'sample_data']

# %%
df = pd.read_csv('COVID19_line_list_data.csv')

# %%
df.head(2)
# Out:
#    id  case_in_country reporting date  ...  Unnamed: 24 Unnamed: 25 Unnamed: 26
# 0   1              NaN      1/20/2020  ...          NaN         NaN         NaN
# 1   2              NaN      1/20/2020  ...          NaN         NaN         NaN
#
# [2 rows x 27 columns]

# %%
df.tail(2)
# Out:
#         id  case_in_country  ... Unnamed: 25  Unnamed: 26
# 1083  1084              1.0  ...         NaN          NaN
# 1084  1085              1.0  ...         NaN          NaN
#
# [2 rows x 27 columns]

# %%
#df['reporting date'] = pd.to_datetime(df['reporting date'])

# %%
#df.set_index('reporting date',inplace=True)

# %%
#df.sort_index()

# %%
df.head(2)
# Out:
#                 id  case_in_country  ...  Unnamed: 25 Unnamed: 26
# reporting date                       ...
# 2020-01-20       1              NaN  ...          NaN         NaN
# 2020-01-20       2              NaN  ...          NaN         NaN
#
# [2 rows x 26 columns]

# %%
df.sample(5)
# Out:
#       id  case_in_country reporting date  ...  Unnamed: 24 Unnamed: 25 Unnamed: 26
# 540  541             91.0      2/25/2020  ...          NaN         NaN         NaN
# 264  265             29.0      2/13/2020  ...          NaN         NaN         NaN
# 600  601             58.0      2/20/2020  ...          NaN         NaN         NaN
# 319  320             84.0      2/21/2020  ...          NaN         NaN         NaN
# 578  579             36.0      2/19/2020  ...          NaN         NaN         NaN
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (1085, 27)

# %%
df.groupby('country').agg(avg_age = ('age','mean'), min_age = ('age','min'), max_age = ('age','max'))
# Out:
#                avg_age  min_age  max_age
# country
# Afghanistan  35.000000    35.00     35.0
# Algeria            NaN      NaN      NaN
# Australia    42.000000     8.00     65.0
# Austria      24.000000    24.00     24.0
# Bahrain            NaN      NaN      NaN
# Belgium            NaN      NaN      NaN
# Cambodia     60.000000    60.00     60.0
# Canada       42.583333    25.00     65.0
# China        49.000000     2.00     89.0
# Croatia            NaN      NaN      NaN
# Egypt              NaN      NaN      NaN
# Finland      32.000000    32.00     32.0
# France       46.611111     9.00     80.0
# Germany      40.214286    24.00     60.0
# Hong Kong    56.075269    16.00     96.0
# India              NaN      NaN      NaN
# Iran               NaN      NaN      NaN
# Israel             NaN      NaN      NaN
# Italy        35.000000    35.00     35.0
# Japan        55.462366     5.00     85.0
# Kuwait             NaN      NaN      NaN
# Lebanon      45.000000    45.00     45.0
# ...

# %%
df.head(2)
# Out:
#    id  case_in_country reporting date  ...  Unnamed: 24 Unnamed: 25 Unnamed: 26
# 0   1              NaN      1/20/2020  ...          NaN         NaN         NaN
# 1   2              NaN      1/20/2020  ...          NaN         NaN         NaN
#
# [2 rows x 27 columns]

# %%
df.pivot_table(index='country', columns='gender', values='age',aggfunc='mean').T.style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_3d9b7028_682b_11ea_bf39_0242ac1c0002row0_col4 {
#             background-color:  yellow;
#         }    #T_3d9b7028_682b_11ea_bf39_0242ac1c0002row0_col7 {
#             background-color:  yellow;
#         }    #T_3d9b7028_682b_11ea_bf39_0242ac1c0002row0_col10 {
#             background-color:  yellow;
#         }    #T_3d9b7028_682b_11ea_bf39_0242ac1c0002row0_col11 {
#             background-color:  yellow;
#         }    #T_3d9b7028_682b_11ea_bf39_0242ac1c0002row0_col13 {
#             background-color:  yellow;
#         }    #T_3d9b7028_682b_11ea_bf39_0242ac1c0002row0_col14 {
#             background-color:  yellow;
#         }    #T_3d9b7028_682b_11ea_bf39_0242ac1c0002row0_col17 {
#             background-color:  yellow;
#         }    #T_3d9b7028_682b_11ea_bf39_0242ac1c0002row0_col18 {
#             background-color:  yellow;
#         }    #T_3d9b7028_682b_11ea_bf39_0242ac1c0002row0_col20 {
#             background-color:  yellow;
# ...

# %%
df.groupby(['country','gender']).agg(avg_age = ('age','mean')).reset_index()
# Out:
#         country  gender    avg_age
# 0       Algeria    male        NaN
# 1     Australia  female  38.333333
# 2     Australia    male  44.444444
# 3       Bahrain  female        NaN
# 4       Bahrain    male        NaN
# 5      Cambodia    male  60.000000
# 6        Canada  female  41.250000
# 7        Canada    male  45.250000
# 8         China  female  46.791667
# 9         China    male  50.347458
# 10      Croatia    male        NaN
# 11      Finland  female  32.000000
# 12       France  female  39.833333
# 13       France    male  52.600000
# 14      Germany  female  35.000000
# 15      Germany    male  41.083333
# 16    Hong Kong  female  59.260870
# 17    Hong Kong    male  52.957447
# 18        India  female        NaN
# 19       Israel  female        NaN
# 20        Italy  female        NaN
# 21        Italy    male  35.000000
# 22        Japan  female  54.000000
# 23        Japan    male  56.652893
# 24       Kuwait  female        NaN
# 25      Lebanon  female  45.000000
# ...

# %%
pd.crosstab(index=df['country'], columns=df['gender']).T
# Out:
# country  Algeria  Australia  Bahrain  Cambodia  ...  UAE  UK  USA  Vietnam
# gender                                          ...
# female         0          6       11         0  ...    3   3    3        4
# male           1          9        4         1  ...    4   5    6        4
#
# [2 rows x 33 columns]

# %%
df.groupby(['country','gender']).size().reset_index(name='count')
# Out:
#         country  gender  count
# 0       Algeria    male      1
# 1     Australia  female      6
# 2     Australia    male      9
# 3       Bahrain  female     11
# 4       Bahrain    male      4
# 5      Cambodia    male      1
# 6        Canada  female      8
# 7        Canada    male      4
# 8         China  female     73
# 9         China    male    124
# 10      Croatia    male      1
# 11      Finland  female      1
# 12       France  female      7
# 13       France    male     13
# 14      Germany  female      7
# 15      Germany    male     21
# 16    Hong Kong  female     47
# 17    Hong Kong    male     47
# 18        India  female      1
# 19       Israel  female      1
# 20        Italy  female      1
# 21        Italy    male      2
# 22        Japan  female     64
# 23        Japan    male    121
# 24       Kuwait  female      1
# 25      Lebanon  female      1
# 26     Malaysia  female     13
# 27     Malaysia    male     10
# 28        Nepal    male      1
# ...

# %%
plot_covid(option='recovered')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9659bc07-407b-4e5b-b2eb-21681ffdb9b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9659bc07-407b-4e5b-b2eb-21681ffdb9b0")) {
#                     Plotly.newPlot(
#                         '9659bc07-407b-4e5b-b2eb-21681ffdb9b0',
# ...

# %%
df_confirmed.head(2)
# Out:
#   Province/State Country/Region   Lat  ...  3/14/20  3/15/20  3/16/20
# 0            NaN       Thailand  15.0  ...       82      114      147
# 1            NaN          Japan  36.0  ...      773      839      825
#
# [2 rows x 59 columns]

# %%
df_confirmed.groupby('Country/Region').agg('sum').loc['Australia'].iloc[2:]
# Out:
# 1/22/20      0.0
# 1/23/20      0.0
# 1/24/20      0.0
# 1/25/20      0.0
# 1/26/20      4.0
# 1/27/20      5.0
# 1/28/20      5.0
# 1/29/20      6.0
# 1/30/20      9.0
# 1/31/20      9.0
# 2/1/20      12.0
# 2/2/20      12.0
# 2/3/20      12.0
# 2/4/20      13.0
# 2/5/20      13.0
# 2/6/20      14.0
# 2/7/20      15.0
# 2/8/20      15.0
# 2/9/20      15.0
# 2/10/20     15.0
# 2/11/20     15.0
# 2/12/20     15.0
# 2/13/20     15.0
# 2/14/20     15.0
# 2/15/20     15.0
# 2/16/20     15.0
# 2/17/20     15.0
# 2/18/20     15.0
# 2/19/20     15.0
# 2/20/20     15.0
# 2/21/20     19.0
# 2/22/20     22.0
# 2/23/20     22.0
# 2/24/20     22.0
# 2/25/20     22.0
# 2/26/20     22.0
# 2/27/20     23.0
# 2/28/20     23.0
# 2/29/20     25.0
# 3/1/20      27.0
# 3/2/20      30.0
# 3/3/20      39.0
# 3/4/20      52.0
# 3/5/20      55.0
# 3/6/20      60.0
# 3/7/20      63.0
# 3/8/20      76.0
# 3/9/20      91.0
# 3/10/20    107.0
# 3/11/20    128.0
# 3/12/20    128.0
# 3/13/20    200.0
# ...

# %%
df_confirmed.groupby('Country/Region').agg(country_total=(df_confirmed.columns[-1],'sum')).loc
# Out:
#                                 country_total
# Country/Region
# Afghanistan                                21
# Albania                                    51
# Algeria                                    54
# Andorra                                     2
# Antigua and Barbuda                         1
# ...                                       ...
# Uruguay                                     8
# Uzbekistan                                  6
# Venezuela                                  17
# Vietnam                                    61
# occupied Palestinian territory              0
#
# [156 rows x 1 columns]

# %%
df.shape
# Out:
# (1085, 27)

# %%
df_first = df.iloc[:500]
df_last = df.iloc[500:]

# %%
df_first.shape, df_last.shape
# Out:
# ((500, 27), (585, 27))

# %%
df_all = pd.concat([df_first,df_last])

# %%
df_all.shape
# Out:
# (1085, 27)

# %%
#merge

# %%
df_confirmed.head(2)
# Out:
#   Province/State Country/Region   Lat  ...  3/14/20  3/15/20  3/16/20
# 0            NaN       Thailand  15.0  ...       82      114      147
# 1            NaN          Japan  36.0  ...      773      839      825
#
# [2 rows x 59 columns]

# %%
df_death.head(2)
# Out:
#   Province/State Country/Region   Lat  ...  3/14/20  3/15/20  3/16/20
# 0            NaN       Thailand  15.0  ...        1        1        1
# 1            NaN          Japan  36.0  ...       22       22       27
#
# [2 rows x 59 columns]

# %%
df_reduced = df_death.loc[:,['Country/Region','Lat','Long','3/16/20']]

# %%
df_reduced.head(2)
# Out:
#   Country/Region   Lat   Long  3/16/20
# 0       Thailand  15.0  101.0        1
# 1          Japan  36.0  138.0       27

# %%
df_confirmed['geo_location'] = df_confirmed['Lat'].astype('str') + '_' + df_confirmed['Long'].astype('str')

# %%
df_reduced['geo_location'] = df_reduced['Lat'].astype('str') + '_' + df_reduced['Long'].astype('str')

# %%
df_reduced.head()
# Out:
#   Country/Region      Lat      Long  3/16/20     geo_location
# 0       Thailand  15.0000  101.0000        1       15.0_101.0
# 1          Japan  36.0000  138.0000       27       36.0_138.0
# 2      Singapore   1.2833  103.8333        0  1.2833_103.8333
# 3          Nepal  28.1667   84.2500        0    28.1667_84.25
# 4       Malaysia   2.5000  112.5000        0        2.5_112.5

# %%
df_confirmed.head()
# Out:
#   Province/State Country/Region      Lat  ...  3/15/20  3/16/20     geo_location
# 0            NaN       Thailand  15.0000  ...      114      147       15.0_101.0
# 1            NaN          Japan  36.0000  ...      839      825       36.0_138.0
# 2            NaN      Singapore   1.2833  ...      226      243  1.2833_103.8333
# 3            NaN          Nepal  28.1667  ...        1        1    28.1667_84.25
# 4            NaN       Malaysia   2.5000  ...      428      566        2.5_112.5
#
# [5 rows x 60 columns]

# %%
df_merged = pd.merge(df_confirmed,df_reduced,on='geo_location',how='left', suffixes=('_confirmed', '_death'))

# %%
df_confirmed.shape
# Out:
# (463, 60)

# %%
import pandas_profiling

# %%
profile = pandas_profiling.ProfileReport(df)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_profiling/describe.py:392: FutureWarning:
#
# The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.

# %%
df.head()
# Out:
#    id  case_in_country reporting date  ...  Unnamed: 24 Unnamed: 25 Unnamed: 26
# 0   1              NaN      1/20/2020  ...          NaN         NaN         NaN
# 1   2              NaN      1/20/2020  ...          NaN         NaN         NaN
# 2   3              NaN      1/21/2020  ...          NaN         NaN         NaN
# 3   4              NaN      1/21/2020  ...          NaN         NaN         NaN
# 4   5              NaN      1/21/2020  ...          NaN         NaN         NaN
#
# [5 rows x 27 columns]

# %%
profile
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...
