# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
# %matplotlib inline

# %%
np.mean([1,2,3,4])
# Out:
# 2.5

# %%
train = pd.read_csv("train.csv")

# %%
train.shape
# Out:
# (333, 15)

# %% [markdown]
# - https://www.kaggle.com/c/boston-housing/overview
# - https://colab.research.google.com/

# %%
train.describe()
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean   250.951952    3.360341   10.689189   11.293483    0.060060    0.557144
# std    147.859438    7.352272   22.674762    6.998123    0.237956    0.114955
# min      1.000000    0.006320    0.000000    0.740000    0.000000    0.385000
# 25%    123.000000    0.078960    0.000000    5.130000    0.000000    0.453000
# 50%    244.000000    0.261690    0.000000    9.900000    0.000000    0.538000
# 75%    377.000000    3.678220   12.500000   18.100000    0.000000    0.631000
# max    506.000000   73.534100  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean     6.265619   68.226426    3.709934    9.633634  409.279279   18.448048
# std      0.703952   28.133344    1.981123    8.742174  170.841988    2.151821
# min      3.561000    6.000000    1.129600    1.000000  188.000000   12.600000
# 25%      5.884000   45.400000    2.122400    4.000000  279.000000   17.400000
# 50%      6.202000   76.700000    3.092300    5.000000  330.000000   19.000000
# 75%      6.595000   93.800000    5.116700   24.000000  666.000000   20.200000
# max      8.725000  100.000000   10.710300   24.000000  711.000000   21.200000
#
#             black       lstat        medv
# count  333.000000  333.000000  333.000000
# mean   359.466096   12.515435   22.768769
# std     86.584567    7.067781    9.173468
# min      3.500000    1.730000    5.000000
# 25%    376.730000    7.180000   17.400000
# 50%    392.050000   10.970000   21.600000
# 75%    396.240000   16.420000   25.000000
# max    396.900000   37.970000   50.000000

# %%
train.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
train.tail()
# Out:
#       ID     crim   zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 328  500  0.17783  0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 328     19.2  395.77  15.10  17.5
# 329     21.0  391.99   9.67  22.4
# 330     21.0  396.90   9.08  20.6
# 331     21.0  396.90   5.64  23.9
# 332     21.0  396.90   7.88  11.9

# %%
train.shape
# Out:
# (333, 15)

# %%
train.describe()
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean   250.951952    3.360341   10.689189   11.293483    0.060060    0.557144
# std    147.859438    7.352272   22.674762    6.998123    0.237956    0.114955
# min      1.000000    0.006320    0.000000    0.740000    0.000000    0.385000
# 25%    123.000000    0.078960    0.000000    5.130000    0.000000    0.453000
# 50%    244.000000    0.261690    0.000000    9.900000    0.000000    0.538000
# 75%    377.000000    3.678220   12.500000   18.100000    0.000000    0.631000
# max    506.000000   73.534100  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean     6.265619   68.226426    3.709934    9.633634  409.279279   18.448048
# std      0.703952   28.133344    1.981123    8.742174  170.841988    2.151821
# min      3.561000    6.000000    1.129600    1.000000  188.000000   12.600000
# 25%      5.884000   45.400000    2.122400    4.000000  279.000000   17.400000
# 50%      6.202000   76.700000    3.092300    5.000000  330.000000   19.000000
# 75%      6.595000   93.800000    5.116700   24.000000  666.000000   20.200000
# max      8.725000  100.000000   10.710300   24.000000  711.000000   21.200000
#
#             black       lstat        medv
# count  333.000000  333.000000  333.000000
# mean   359.466096   12.515435   22.768769
# std     86.584567    7.067781    9.173468
# min      3.500000    1.730000    5.000000
# 25%    376.730000    7.180000   17.400000
# 50%    392.050000   10.970000   21.600000
# 75%    396.240000   16.420000   25.000000
# max    396.900000   37.970000   50.000000

# %%
sns.distplot(train["medv"])
# Out:
# /Users/arunprakash/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1626: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(train["medv"]);

# %% [markdown]
# # Modeling

# %%
from sklearn.model_selection import train_test_split

# %%
train.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
train.drop("ID",axis=1, inplace=True)

# %%
train.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 3  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
# 4  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311     15.2
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  394.63   2.94  33.4
# 3  396.90   5.33  36.2
# 4  395.60  12.43  22.9

# %%
X_train,X_val,y_train, y_val = train_test_split(
    train.drop("medv", axis=1), train["medv"], test_size=0.2)

# %%
X_train.shape, X_val.shape
# Out:
# ((266, 14), (67, 14))

# %%
y_train.shape, y_val.shape
# Out:
# ((266,), (67,))

# %%
X_train.head()
# Out:
#       ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 184  274  0.22188  20.0   6.96     1  0.464  7.691  51.8  4.3665    3  223
# 95   140  0.54452   0.0  21.89     0  0.624  6.151  97.9  1.6687    4  437
# 210  316  0.25356   0.0   9.90     0  0.544  5.705  77.7  3.9450    4  304
# 23    41  0.03359  75.0   2.95     0  0.428  7.024  15.8  5.4011    3  252
# 105  157  2.44668   0.0  19.58     0  0.871  5.272  94.0  1.7364    5  403
#
#      ptratio   black  lstat
# 184     18.6  390.77   6.58
# 95      21.2  396.90  18.46
# 210     18.4  396.42  11.50
# 23      18.3  395.62   1.98
# 105     14.7   88.63  16.14

# %%
X_val.head()
# Out:
#       ID      crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 111  165   2.24236  0.0  19.58     0  0.605  5.854   91.8  2.4220    5  403
# 307  469  15.57570  0.0  18.10     0  0.580  5.926   71.0  2.9084   24  666
# 77   117   0.13158  0.0  10.01     0  0.547  6.176   72.5  2.7301    6  432
# 326  494   0.17331  0.0   9.69     0  0.585  5.707   54.0  2.3817    6  391
# 107  160   1.42502  0.0  19.58     0  0.871  6.510  100.0  1.7659    5  403
#
#      ptratio   black  lstat
# 111     14.7  395.11  11.64
# 307     20.2  368.74  18.13
# 77      17.8  393.30  12.04
# 326     19.2  396.90  12.01
# 107     14.7  364.31   7.39

# %% [markdown]
# # Model building

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
y_pred = model.predict(X_val)

# %%
y_pred
# Out:
# array([19.1, 14.6, 19.3, 16.2, 25. , 31.2, 29.1, 25. , 37.6, 37.9, 25. ,
#        20.4, 12.7, 31. ,  9.5, 16.7, 23.3,  7.2, 20.6, 23.9, 10.8, 22.8,
#        30.8, 27.9, 19.8, 19.4, 29.4, 24.7, 17.4, 19.4, 19.1, 22.6, 25. ,
#        33.8, 16.1, 14.1, 21.7, 18.6, 22.2, 33.4, 32.7, 22.2, 23.9, 22.8,
#        16.1, 20.6, 19.4, 17.1, 14.9, 22.8, 26.5, 20.6, 19.1, 22.6, 35.2,
#        20.4, 20.1, 19.1, 32.4, 35.4, 13.9, 13.5, 18.4, 17.4, 16.1, 43.5,
#        17.8])

# %%
y_val.values
# Out:
# array([22.7, 19.1, 21.2, 21.8, 23.3, 24.5, 30.5, 27.5, 50. , 50. , 24.3,
#        18.5,  8.3, 17.8, 12.3, 15.2, 22. ,  5.6, 22.5, 21.6,  8.3, 28. ,
#        31.1, 50. , 20.1, 23.1, 31.5, 21.2, 17.6, 14.8, 19.6, 22.9, 27. ,
#        36.5, 15.2, 14.3, 16.6, 19.3, 24.7, 36.1, 32.2, 24.6, 23.6, 28.5,
#        18.4, 21.8, 15.6, 14.1, 12.6, 27.9, 23.7, 23. , 15.4, 22.6, 43.1,
#        20.6, 21.4, 12.5, 35.1, 33.4, 13.3, 15. , 16.2, 17.1, 19.5, 50. ,
#        14.6])

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
np.sqrt(mean_squared_error(y_val, y_pred))
# Out:
# 4.870195680888936

# %%
r2_score(y_val, y_pred)
# Out:
# 0.751142386457159

# %%
import pydotplus #pip install pydotplus
from sklearn.tree import export_graphviz

def tree_graph_to_png(tree, feature_names, png_file_to_save):
    tree_str = export_graphviz(tree, feature_names=feature_names, 
                                     filled=True, out_file=None)
    graph = pydotplus.graph_from_dot_data(tree_str)  
    graph.write_png(png_file_to_save)

# %%
tree_graph_to_png(tree=model, feature_names=X_train.columns,
                  png_file_to_save='tree1.png')

# %%
X_train.head()
# Out:
#       ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 184  274  0.22188  20.0   6.96     1  0.464  7.691  51.8  4.3665    3  223
# 95   140  0.54452   0.0  21.89     0  0.624  6.151  97.9  1.6687    4  437
# 210  316  0.25356   0.0   9.90     0  0.544  5.705  77.7  3.9450    4  304
# 23    41  0.03359  75.0   2.95     0  0.428  7.024  15.8  5.4011    3  252
# 105  157  2.44668   0.0  19.58     0  0.871  5.272  94.0  1.7364    5  403
#
#      ptratio   black  lstat
# 184     18.6  390.77   6.58
# 95      21.2  396.90  18.46
# 210     18.4  396.42  11.50
# 23      18.3  395.62   1.98
# 105     14.7   88.63  16.14

# %%
y_train
# Out:
# 184    35.2
# 95     17.8
# 210    16.2
# 23     34.9
# 105    13.1
# 12     20.2
# 214    23.8
# 237    22.6
# 83     20.5
# 70     19.3
# 251    11.3
# 254    10.5
# 10     19.9
# 233    18.6
# 163    25.1
# 118    23.1
# 271     8.8
# 180    30.7
# 74     19.4
# 324    13.6
# 263     7.2
# 86     15.7
# 44     19.4
# 137    29.1
# 129    32.5
# 62     28.7
# 4      22.9
# 31     19.7
# 65     20.6
# 110    50.0
#        ...
# 224    19.0
# 155    37.6
# 276    11.0
# 8      20.4
# 198    20.3
# 58     26.6
# 256    11.5
# 323     8.1
# 68     26.5
# 45     22.0
# 103    19.4
# 172    24.8
# 170    26.2
# 296    13.5
# 270    10.4
# 203    28.4
# 169    24.5
# 50     24.1
# 187    35.4
# 238    25.0
# 261     5.0
# 34     18.9
# 197    27.1
# 102    21.5
# 125    37.2
# 191    22.0
# 288    10.8
# 275    10.9
# 0      24.0
# 304    19.9
# Name: medv, Length: 266, dtype: float64

# %% [markdown]
# # RandomForest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
# Out:
# /Users/arunprakash/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
train.columns
# Out:
# Index(['ID', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad',
#        'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
model = RandomForestRegressor(n_estimators=100, max_depth=5, max_features= 0.5 )

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=5,
#            max_features=0.5, max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
y_pred = model.predict(X_val)

# %%
y_pred
# Out:
# array([20.48925556, 15.82592065, 20.72640812, 20.10149611, 25.79231813,
#        26.54156329, 29.07824752, 26.61822045, 42.10916505, 36.38804715,
#        24.81299316, 20.70028995, 11.57462193, 24.82990421, 12.50404464,
#        16.09416819, 20.54803112,  9.47378532, 21.48996189, 23.43389587,
#        10.03979951, 26.57074255, 28.87603184, 31.72179941, 22.41157718,
#        20.96855225, 27.85261388, 23.58705052, 21.04682391, 17.51460246,
#        19.856771  , 23.4874626 , 25.7875243 , 34.72684253, 17.11680569,
#        16.14081228, 20.25596514, 22.34344552, 24.37885993, 33.191448  ,
#        31.36269891, 24.18141769, 24.37312624, 29.89568022, 15.7519407 ,
#        20.25128548, 16.69955297, 14.74766006, 15.33905601, 27.2053876 ,
#        25.64965144, 20.29271235, 15.9964501 , 23.33495425, 36.94382782,
#        22.0418646 , 20.55600726, 15.42869825, 30.37403985, 34.6108264 ,
#        14.64518561, 18.13590971, 17.02099545, 19.07238758, 18.1160434 ,
#        43.38492289, 15.57471138])

# %%
y_val.values
# Out:
# array([22.7, 19.1, 21.2, 21.8, 23.3, 24.5, 30.5, 27.5, 50. , 50. , 24.3,
#        18.5,  8.3, 17.8, 12.3, 15.2, 22. ,  5.6, 22.5, 21.6,  8.3, 28. ,
#        31.1, 50. , 20.1, 23.1, 31.5, 21.2, 17.6, 14.8, 19.6, 22.9, 27. ,
#        36.5, 15.2, 14.3, 16.6, 19.3, 24.7, 36.1, 32.2, 24.6, 23.6, 28.5,
#        18.4, 21.8, 15.6, 14.1, 12.6, 27.9, 23.7, 23. , 15.4, 22.6, 43.1,
#        20.6, 21.4, 12.5, 35.1, 33.4, 13.3, 15. , 16.2, 17.1, 19.5, 50. ,
#        14.6])

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
np.sqrt(mean_squared_error(y_val, y_pred))
# Out:
# 3.8106869487831854

# %%
r2_score(y_val, y_pred)
# Out:
# 0.8476422133776024

# %%
import pandas as pd
feature_importances = pd.DataFrame(model.feature_importances_,
                                   index = X_train.columns,
                                    columns=['importance']).sort_values('importance',                                                                 ascending=False)

# %%
feature_importances
# Out:
#          importance
# rm         0.397515
# lstat      0.309746
# dis        0.050975
# crim       0.044300
# ID         0.041365
# nox        0.037510
# ptratio    0.034994
# indus      0.030432
# age        0.018520
# tax        0.015464
# black      0.009822
# rad        0.006508
# zn         0.002446
# chas       0.000404

# %%
feature_importances.plot(kind ='bar')

# %% [markdown]
# # Confidence based on RF

# %%
# %time preds = np.stack([t.predict(X_val) for t in model.estimators_])
np.mean(preds[:,2]), np.std(preds[:,2])
# Out:
# CPU times: user 13.3 ms, sys: 2.13 ms, total: 15.4 ms
# Wall time: 13.5 ms
# (20.726408117368102, 1.2127766278619472)

# %%
preds[0]
# Out:
# array([20.94583333, 14.84      , 19.8125    , 19.17692308, 50.        ,
#        24.07948718, 24.07948718, 20.94583333, 48.5       , 37.66666667,
#        50.        , 24.07948718, 10.82857143, 13.5       ,  9.19333333,
#        15.87142857, 19.8125    ,  9.19333333, 19.8125    , 24.07948718,
#         9.19333333, 24.07948718, 24.07948718, 50.        , 19.8125    ,
#        24.07948718, 24.07948718, 24.07948718, 19.8125    , 19.8125    ,
#        17.98461538, 24.07948718, 24.07948718, 33.19      , 19.8125    ,
#        19.17692308, 19.8125    , 20.94583333, 24.07948718, 33.19      ,
#        33.19      , 24.07948718, 24.07948718, 24.07948718, 15.87142857,
#        22.93333333, 17.98461538, 13.5       , 13.5       , 24.07948718,
#        22.93333333, 22.93333333, 19.66      , 20.94583333, 33.19      ,
#        24.07948718, 13.5       , 15.87142857, 24.07948718, 36.2       ,
#        10.82857143, 14.00833333, 17.98461538, 17.98461538, 19.8125    ,
#        37.66666667, 19.66      ])

# %% [markdown]
# # Feature importances

# %% [markdown]
# # Dendogram for redundant features

# %%
from scipy.cluster import hierarchy as hc

# %%
import scipy

# %%
corr = np.round(scipy.stats.spearmanr(X_train).correlation, 4)
corr_condensed = hc.distance.squareform(1-corr)
z = hc.linkage(corr_condensed, method='average')
fig = plt.figure(figsize=(16,10))
dendrogram = hc.dendrogram(z, labels=X_train.columns, orientation='left', leaf_font_size=16)
plt.show()

# %% [markdown]
# # Remove redudant feats and test

# %% [markdown]
# # Partial dependence plots

# %%
from pdpbox import pdp
from plotnine import *

# %%
#conda install ggplot

# %%
def plot_pdp(feat, clusters=None, feat_name=None):
    feat_name = feat_name or feat
    p = pdp.pdp_isolate(model, X_train, feat)
    return pdp.pdp_plot(p, feat_name, plot_lines=True,
                        cluster=clusters is not None,
                        n_cluster_centers=clusters)

# %%
X_train.columns
# Out:
# Index(['ID', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad',
#        'tax', 'ptratio', 'black', 'lstat'],
#       dtype='object')

# %%
plot_pdp('lstat')

# %%
plot_pdp('lstat', clusters=3)

# %%
feats = ['lstat', 'rm']
p = pdp.pdp_interact(model, X_train, feats)
pdp.pdp_interact_plot(p, feats)

# %%
test = pd.read_csv("test.csv")

# %%
test.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 0   3  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 1   6  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 2   8  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 3   9  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 4  10  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
#
#    ptratio   black  lstat
# 0     17.8  392.83   4.03
# 1     18.7  394.12   5.21
# 2     15.2  396.90  19.15
# 3     15.2  386.63  29.93
# 4     15.2  386.71  17.10

# %%
test.drop("ID", axis=1, inplace=True)

# %%
test.head()
# Out:
#       crim    zn  indus  chas    nox     rm    age     dis  rad  tax  ptratio  \
# 0  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 1  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 2  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 3  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 4  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#     black  lstat
# 0  392.83   4.03
# 1  394.12   5.21
# 2  396.90  19.15
# 3  386.63  29.93
# 4  386.71  17.10

# %%
model.predict(test)
# Out:
# array([36.1442215 , 24.57844265, 18.09891863, 17.2411881 , 18.46102704,
#        19.52488889, 20.59168812, 16.94554435, 17.17315752, 19.79861563,
#        20.17551767, 21.5170278 , 16.67921224, 16.29395621, 22.1065085 ,
#        21.59931986, 22.34098898, 26.38211525, 18.15685694, 23.48465701,
#        21.99284582, 23.41140018, 22.34098898, 21.39235651, 21.1474581 ,
#        21.79403574, 23.41140018, 23.18727085, 22.65402125, 25.74017417,
#        40.10545905, 42.60133929, 34.51811382, 20.31446984, 16.93102595,
#        20.40541582, 18.50361645, 17.34687746, 19.29987642, 20.3650739 ,
#        16.29422792, 20.17551767, 20.34899386, 16.98892116, 16.22508363,
#        15.92885493, 17.37962951, 15.45492817, 20.70098227, 21.72448023,
#        16.85018029, 30.9595954 , 49.03142857, 21.09316134, 22.3096973 ,
#        22.39423978, 27.81636758, 46.11506944, 37.66428933, 33.96201205,
#        31.89406965, 45.67444444, 18.30696574, 17.58327937, 18.19783497,
#        19.6877853 , 22.18251074, 23.31728517, 18.26271299, 21.89146021,
#        28.23704731, 44.59765074, 36.96645536, 33.58112203, 23.48465701,
#        26.16352431, 21.32994179, 18.74061943, 21.57394311, 32.98649194,
#        23.60421405, 22.41501877, 42.37176893, 42.87458009, 34.70423195,
#        32.35004058, 43.75666342, 20.76891243, 20.59247562, 29.33748179,
#        32.42556057, 29.55376922, 23.7996932 , 46.77661706, 23.78233799,
#        25.53051385, 34.60529742, 21.20093013, 25.2070309 , 24.79456229,
#        33.21534993, 30.60323194, 28.72635828, 21.6220494 , 23.43932622,
#        20.83724578, 23.431899  , 22.74877376, 20.84469003, 23.29484344,
#        23.17418404, 21.03873264, 22.83133208, 22.12900772, 20.99932076,
#        21.1115798 , 20.75197991, 23.92446769, 26.1736694 , 27.58053162,
#        22.58011075, 23.12518032, 20.18533505, 18.56344689, 39.6120184 ,
#        42.87536543, 28.68037879, 13.3261481 , 13.51281477, 16.99280092,
#        14.09052712,  9.13907525, 10.44798533, 14.47302685, 18.16710248,
#        16.10397039, 14.25519731, 11.48534121, 13.48167842,  8.13049787,
#         8.9012062 , 15.35744211, 15.25176127, 22.23782782, 13.78329699,
#        12.66490116, 11.74312714, 14.58427395, 17.17384528, 20.46088017,
#        15.68642092, 15.96042932, 18.30540658, 12.17341165, 12.09848909,
#        10.07225319, 16.1294677 , 15.81198754, 15.03417171, 13.83921167,
#        15.81141493, 17.8489409 , 25.22570317, 16.15462174, 30.76761993,
#        20.91805033, 14.95366002, 20.41317831, 18.03723427, 17.61635332,
#        20.41317831, 20.12908025, 27.72146759])
