# %%
print("hello")
# Out:
# hello

# %%
1+10
# Out:
# 11

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Data collection

# %%
1+1
# Out:
# 2

# %% [markdown]
# 1+1

# %% [markdown]
# # Data collection

# %%
data = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",
                   names=["sepal_len", "sepal_width", "petal_len", "petal_width", "prediction"])

# %%
data.head(100)
# Out:
#     sepal_len  sepal_width  petal_len  petal_width  prediction
# 0         5.1          3.5        1.4          0.2           2
# 1         4.9          3.0        1.4          0.2           2
# 2         4.7          3.2        1.3          0.2           2
# 3         4.6          3.1        1.5          0.2           2
# 4         5.0          3.6        1.4          0.2           2
# 5         5.4          3.9        1.7          0.4           2
# 6         4.6          3.4        1.4          0.3           2
# 7         5.0          3.4        1.5          0.2           2
# 8         4.4          2.9        1.4          0.2           2
# 9         4.9          3.1        1.5          0.1           2
# 10        5.4          3.7        1.5          0.2           2
# 11        4.8          3.4        1.6          0.2           2
# 12        4.8          3.0        1.4          0.1           2
# 13        4.3          3.0        1.1          0.1           2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_len      150 non-null float64
# sepal_width    150 non-null float64
# petal_len      150 non-null float64
# petal_width    150 non-null float64
# prediction     150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
data.tail()
# Out:
#      sepal_len  sepal_width  petal_len  petal_width      prediction
# 145        6.7          3.0        5.2          2.3  Iris-virginica
# 146        6.3          2.5        5.0          1.9  Iris-virginica
# 147        6.5          3.0        5.2          2.0  Iris-virginica
# 148        6.2          3.4        5.4          2.3  Iris-virginica
# 149        5.9          3.0        5.1          1.8  Iris-virginica

# %%
data.describe()
# Out:
#         sepal_len  sepal_width   petal_len  petal_width
# count  150.000000   150.000000  150.000000   150.000000
# mean     5.843333     3.054000    3.758667     1.198667
# std      0.828066     0.433594    1.764420     0.763161
# min      4.300000     2.000000    1.000000     0.100000
# 25%      5.100000     2.800000    1.600000     0.300000
# 50%      5.800000     3.000000    4.350000     1.300000
# 75%      6.400000     3.300000    5.100000     1.800000
# max      7.900000     4.400000    6.900000     2.500000

# %%
data.shape
# Out:
# (150, 5)

# %%
data.columns
# Out:
# Index(['sepal_len', 'sepal_width', 'petal_len', 'petal_width', 'prediction'], dtype='object')

# %%
data.iloc[[0]]
# Out:
#    sepal_len  sepal_width  petal_len  petal_width   prediction
# 0        5.1          3.5        1.4          0.2  Iris-setosa

# %% [markdown]
# # Visualise the data

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x114d7ea20>,
# ...
#       dtype=object)

# %%
data.plot(kind="box")

# %% [markdown]
# # Visualise using seaborn

# %%
data.head()
# Out:
#    sepal_len  sepal_width  petal_len  petal_width   prediction
# 0        5.1          3.5        1.4          0.2  Iris-setosa
# 1        4.9          3.0        1.4          0.2  Iris-setosa
# 2        4.7          3.2        1.3          0.2  Iris-setosa
# 3        4.6          3.1        1.5          0.2  Iris-setosa
# 4        5.0          3.6        1.4          0.2  Iris-setosa

# %%
data["prediction"].value_counts()
# Out:
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        50
# Name: prediction, dtype: int64

# %%
sns.boxplot(data["sepal_len"])
# Out:
# /Users/arunprakash/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
sns.distplot(data["sepal_len"]);
# Out:
# /Users/arunprakash/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1626: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data.plot.hist(alpha=0.7);

# %%
sns.pairplot(data, hue='prediction', diag_kind='kde', size=2);
# Out:
# /Users/arunprakash/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1626: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # Model building

# %%
from sklearn.model_selection import train_test_split

# %%
data.columns
# Out:
# Index(['sepal_len', 'sepal_width', 'petal_len', 'petal_width', 'prediction'], dtype='object')

# %%
data.head()
# Out:
#    sepal_len  sepal_width  petal_len  petal_width   prediction
# 0        5.1          3.5        1.4          0.2  Iris-setosa
# 1        4.9          3.0        1.4          0.2  Iris-setosa
# 2        4.7          3.2        1.3          0.2  Iris-setosa
# 3        4.6          3.1        1.5          0.2  Iris-setosa
# 4        5.0          3.6        1.4          0.2  Iris-setosa

# %%
data["prediction"].value_counts()
# Out:
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        50
# Name: prediction, dtype: int64

# %%
conversion_map = {"Iris-virginica":0, "Iris-versicolor":1,"Iris-setosa":2 }

# %%
data["prediction"] = data["prediction"].map(conversion_map)

# %%
data.head()
# Out:
#    sepal_len  sepal_width  petal_len  petal_width  prediction
# 0        5.1          3.5        1.4          0.2           2
# 1        4.9          3.0        1.4          0.2           2
# 2        4.7          3.2        1.3          0.2           2
# 3        4.6          3.1        1.5          0.2           2
# 4        5.0          3.6        1.4          0.2           2

# %%
X = data[['sepal_len', 'sepal_width', 'petal_len', 'petal_width']]
y = data['prediction']

# %%
X.head()
# Out:
#    sepal_len  sepal_width  petal_len  petal_width
# 0        5.1          3.5        1.4          0.2
# 1        4.9          3.0        1.4          0.2
# 2        4.7          3.2        1.3          0.2
# 3        4.6          3.1        1.5          0.2
# 4        5.0          3.6        1.4          0.2

# %%
y.head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: prediction, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25)

# %%
X.head()
# Out:
#    sepal_len  sepal_width  petal_len  petal_width
# 0        5.1          3.5        1.4          0.2
# 1        4.9          3.0        1.4          0.2
# 2        4.7          3.2        1.3          0.2
# 3        4.6          3.1        1.5          0.2
# 4        5.0          3.6        1.4          0.2

# %%
X_train.head()
# Out:
#      sepal_len  sepal_width  petal_len  petal_width
# 75         6.6          3.0        4.4          1.4
# 53         5.5          2.3        4.0          1.3
# 97         6.2          2.9        4.3          1.3
# 15         5.7          4.4        1.5          0.4
# 149        5.9          3.0        5.1          1.8

# %%
X_test.head()
# Out:
#      sepal_len  sepal_width  petal_len  petal_width
# 39         5.1          3.4        1.5          0.2
# 38         4.4          3.0        1.3          0.2
# 102        7.1          3.0        5.9          2.1
# 2          4.7          3.2        1.3          0.2
# 74         6.4          2.9        4.3          1.3

# %%
X_train.shape, X_test.shape
# Out:
# ((112, 4), (38, 4))

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %% [markdown]
# # Evaluation

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([2, 2, 0, 2, 1, 2, 1, 2, 1, 0, 1, 2, 1, 2, 1, 1, 0, 1, 1, 2, 1, 0,
#        2, 2, 0, 0, 2, 1, 1, 2, 2, 0, 0, 0, 0, 1, 0, 0])

# %%
X_test.head()
# Out:
#      sepal_len  sepal_width  petal_len  petal_width
# 39         5.1          3.4        1.5          0.2
# 38         4.4          3.0        1.3          0.2
# 102        7.1          3.0        5.9          2.1
# 2          4.7          3.2        1.3          0.2
# 74         6.4          2.9        4.3          1.3

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8947368421052632

# %%
cm =confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[12,  4,  0],
#        [ 0,  9,  0],
#        [ 0,  0, 13]])

# %%
sns.heatmap(cm,annot=True)

# %%
conversion_map
# Out:
# {'Iris-setosa': 2, 'Iris-versicolor': 1, 'Iris-virginica': 0}
