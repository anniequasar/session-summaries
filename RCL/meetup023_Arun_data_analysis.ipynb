# %%
print('hello world')
# Out:
# hello world

# %%
import pandas as pd

# %%
df = pd.read_csv('bike_kaggle.csv', parse_dates = ['datetime'], index_col = 0)

# %%
df.dtypes
# Out:
# season          int64
# holiday         int64
# workingday      int64
# weather         int64
# temp          float64
# atemp         float64
# humidity        int64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10886 entries, 2011-01-01 00:00:00 to 2012-12-19 23:00:00
# Data columns (total 11 columns):
# season        10886 non-null int64
# holiday       10886 non-null int64
# workingday    10886 non-null int64
# weather       10886 non-null int64
# temp          10886 non-null float64
# atemp         10886 non-null float64
# humidity      10886 non-null int64
# windspeed     10886 non-null float64
# casual        10886 non-null int64
# registered    10886 non-null int64
# count         10886 non-null int64
# dtypes: float64(3), int64(8)
# memory usage: 1020.6 KB

# %% [markdown]
# # Selecting the data

# %%
df.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered  count
# datetime
# 2011-01-01 00:00:00        81        0.0       3          13     16
# 2011-01-01 01:00:00        80        0.0       8          32     40
# 2011-01-01 02:00:00        80        0.0       5          27     32
# 2011-01-01 03:00:00        75        0.0       3          10     13
# 2011-01-01 04:00:00        75        0.0       0           1      1

# %%
titanic.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %%
titanic['Age']
# Out:
# Name
# Braund, Mr. Owen Harris                                22.0
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    38.0
# Heikkinen, Miss. Laina                                 26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           35.0
# Allen, Mr. William Henry                               35.0
#                                                        ...
# Montvila, Rev. Juozas                                  27.0
# Graham, Miss. Margaret Edith                           19.0
# Johnston, Miss. Catherine Helen "Carrie"                NaN
# Behr, Mr. Karl Howell                                  26.0
# Dooley, Mr. Patrick                                    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic.loc[:,'Age']
# Out:
# Name
# Braund, Mr. Owen Harris                                22.0
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    38.0
# Heikkinen, Miss. Laina                                 26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           35.0
# Allen, Mr. William Henry                               35.0
#                                                        ...
# Montvila, Rev. Juozas                                  27.0
# Graham, Miss. Margaret Edith                           19.0
# Johnston, Miss. Catherine Helen "Carrie"                NaN
# Behr, Mr. Karl Howell                                  26.0
# Dooley, Mr. Patrick                                    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic.iloc[:,4]
# Out:
# Name
# Braund, Mr. Owen Harris                                22.0
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    38.0
# Heikkinen, Miss. Laina                                 26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           35.0
# Allen, Mr. William Henry                               35.0
#                                                        ...
# Montvila, Rev. Juozas                                  27.0
# Graham, Miss. Margaret Edith                           19.0
# Johnston, Miss. Catherine Helen "Carrie"                NaN
# Behr, Mr. Karl Howell                                  26.0
# Dooley, Mr. Patrick                                    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
to_select = ['PassengerId', 'Age']
titanic[to_select].head(2)
# Out:
#                                                     PassengerId   Age
# Name
# Braund, Mr. Owen Harris                                       1  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2  38.0

# %%
titanic.iloc[0:3,[0,4]]
# Out:
#                                                     PassengerId   Age
# Name
# Braund, Mr. Owen Harris                                       1  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2  38.0
# Heikkinen, Miss. Laina                                        3  26.0

# %%
to_select = ['Braund, Mr. Owen Harris', 'Heikkinen, Miss. Laina']

# %%
titanic.loc[to_select, ['Age']]
# Out:
#                           Age
# Name
# Braund, Mr. Owen Harris  22.0
# Heikkinen, Miss. Laina   26.0

# %%
titanic.head(1)
# Out:
#                          PassengerId  Survived  Pclass   Sex   Age  SibSp  \
# Name
# Braund, Mr. Owen Harris            1         0       3  male  22.0      1
#
#                          Parch     Ticket  Fare Cabin Embarked
# Name
# Braund, Mr. Owen Harris      0  A/5 21171  7.25   NaN        S

# %% [markdown]
# # Solution

# %%
a = [1,2,3,4,5]

# %%
a[0:3]
# Out:
# [1, 2, 3]

# %%
a[:3]
# Out:
# [1, 2, 3]

# %%
a[-1]
# Out:
# 5

# %%
a[-3:-1]
# Out:
# [3, 4]

# %%
titanic.iloc[-3:, [1,4]]
# Out:
#                                           Survived   Age
# Name
# Johnston, Miss. Catherine Helen "Carrie"         0   NaN
# Behr, Mr. Karl Howell                            1  26.0
# Dooley, Mr. Patrick                              0  32.0

# %%
select_names = list(titanic.index[-3:])
select_names
# Out:
# ['Johnston, Miss. Catherine Helen "Carrie"',
#  'Behr, Mr. Karl Howell',
#  'Dooley, Mr. Patrick']

# %%
titanic.loc[select_names,['Survived', 'Age']]
# Out:
#                                           Survived   Age
# Name
# Johnston, Miss. Catherine Helen "Carrie"         0   NaN
# Behr, Mr. Karl Howell                            1  26.0
# Dooley, Mr. Patrick                              0  32.0

# %%
titanic.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %%
titanic.iloc[-5:, -3:]
# Out:
#                                            Fare Cabin Embarked
# Name
# Montvila, Rev. Juozas                     13.00   NaN        S
# Graham, Miss. Margaret Edith              30.00   B42        S
# Johnston, Miss. Catherine Helen "Carrie"  23.45   NaN        S
# Behr, Mr. Karl Howell                     30.00  C148        C
# Dooley, Mr. Patrick                        7.75   NaN        Q

# %%
titanic.head(3)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
#
#                                                               Ticket     Fare  \
# Name
# ...

# %%
filt = titanic['Age'] == 25

# %%
titanic[filt].head()
# Out:
#                                        PassengerId  Survived  Pclass     Sex  \
# Name
# Moen, Mr. Sigurd Hansen                         76         0       3    male
# Sobey, Mr. Samuel James Hayden                 135         0       2    male
# Lindahl, Miss. Agda Thorilda Viktoria          247         0       3  female
# Persson, Mr. Ernst Ulrik                       268         1       3    male
# Tornquist, Mr. William Henry                   272         1       3    male
#
#                                         Age  SibSp  Parch      Ticket    Fare  \
# Name
# Moen, Mr. Sigurd Hansen                25.0      0      0      348123   7.650
# Sobey, Mr. Samuel James Hayden         25.0      0      0  C.A. 29178  13.000
# Lindahl, Miss. Agda Thorilda Viktoria  25.0      0      0      347071   7.775
# Persson, Mr. Ernst Ulrik               25.0      1      0      347083   7.775
# Tornquist, Mr. William Henry           25.0      0      0        LINE   0.000
#
# ...

# %%
filt = titanic['Survived'] == 1

# %%
df_filt = titanic[filt]
len(df_filt)
# Out:
# 342

# %%
df_filt.shape
# Out:
# (342, 11)

# %%
filt1 = titanic['Age'] >70
filt2 = titanic['Survived'] == 1

# %%
filt = filt1 & filt2

# %%
titanic[filt]
# Out:
#                                       PassengerId  Survived  Pclass   Sex  \
# Name
# Barkworth, Mr. Algernon Henry Wilson          631         1       1  male
#
#                                        Age  SibSp  Parch Ticket  Fare Cabin  \
# Name
# Barkworth, Mr. Algernon Henry Wilson  80.0      0      0  27042  30.0   A23
#
#                                      Embarked
# Name
# Barkworth, Mr. Algernon Henry Wilson        S

# %%
titanic[(titanic['Age'] >70) & (titanic['Survived'] == 1)]
# Out:
#                                       PassengerId  Survived  Pclass   Sex  \
# Name
# Barkworth, Mr. Algernon Henry Wilson          631         1       1  male
#
#                                        Age  SibSp  Parch Ticket  Fare Cabin  \
# Name
# Barkworth, Mr. Algernon Henry Wilson  80.0      0      0  27042  30.0   A23
#
#                                      Embarked
# Name
# Barkworth, Mr. Algernon Henry Wilson        S

# %%
filt = titanic['Age'].isin([25,26,27,28])

# %%
filt = titanic['Age'].between(25,28)

# %%
titanic[filt]
# Out:
#                                                     PassengerId  Survived  \
# Name
# Heikkinen, Miss. Laina                                        3         1
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             9         1
# Sloper, Mr. William Thompson                                 24         1
# Meyer, Mr. Edgar Joseph                                      35         0
# Turpin, Mrs. William John Robert (Dorothy Ann W...           42         0
# ...                                                         ...       ...
# Shelley, Mrs. William (Imanita Parrish Hall)                881         1
# Banfield, Mr. Frederick James                               884         0
# Sutehall, Mr. Henry Jr                                      885         0
# Montvila, Rev. Juozas                                       887         0
# Behr, Mr. Karl Howell                                       890         1
#
# ...

# %%
titanic.tail(3)
# Out:
#                                           PassengerId  Survived  Pclass  \
# Name
# Johnston, Miss. Catherine Helen "Carrie"          889         0       3
# Behr, Mr. Karl Howell                             890         1       1
# Dooley, Mr. Patrick                               891         0       3
#
#                                              Sex   Age  SibSp  Parch  \
# Name
# Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
# Behr, Mr. Karl Howell                       male  26.0      0      0
# Dooley, Mr. Patrick                         male  32.0      0      0
#
#                                               Ticket   Fare Cabin Embarked
# Name
# Johnston, Miss. Catherine Helen "Carrie"  W./C. 6607  23.45   NaN        S
# Behr, Mr. Karl Howell                         111369  30.00  C148        C
# Dooley, Mr. Patrick                           370376   7.75   NaN        Q

# %%
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0

# %%
df = pd.read_csv('bike_kaggle.csv', index_col = 'datetime')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Ex1

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic = pd.read_csv('titanic.csv', index_col=3)

# %%
titanic.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %%
df.tail()
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88
